# %% [markdown]
# BOARD:
# Como vamos a representar el tablero? Este tiene que ser representado con las dimensiones de settings
# y tambien va a detectar una victoria estas son sus dos responsabolidades.
# Necesitara por lo tanto un metodo que "compruebe la victoria" Va a recibir self y un character de uno de ya que en el tablero los jugadores van a ser representados por un caracter.
# Imagino que sera mejor que el fondo es el "principio" para no tener que recorrerlo entero.

# %% [markdown]
# REPRESETNACION_BOARD:
# La mejor opcion una lista de listas un LOL para representar las columnas y las filas
# Ya que es 4x 4 sera una matriz y comenzara estando rellena de None, nada.
# Pero tenemos que decidir una lista ser una fila o una columna? Sera mejor que sea columna ya que jugamos "tirando en una columna"
# Cada lista es una columna. Y la parte de abajo de la columna sera el principio o el final de la lista?
# Seria mejor que sea

# %% [markdown]
# METODO_JUGAR:
# Es una funcion impura y pecadora porque cambia el entorno del tablera (la matriz) su unica funcion sera
# "meter la ficha"
# ValueError si la columna esta llena o si el indice es de una columa inexistente

# %%
c = [[None]* 4] * 4
print(c)
# Out:
# [[None, None, None, None], [None, None, None, None], [None, None, None, None], [None, None, None, None]]

# %% [markdown]
# REPR
# QUe hace REPR? Devuelve una cadena y deuvleve en forma de cadena algun valor de Python.
# Ej. print(["hola"]) Que es lo que hace print? Un REPR al valor que hay ahi dentro que es una cadena
# le dice: Cual es tu RERPR? (Representacion textual) y el tio devuelve el string y lo printea y resulta que es hola.
# Queremos un REPR para el tablero. QUe deberia representar este REPR? La matriz de alguna forma.
# Hagamoslo simple, lo unico es que podamos verle las tripas.
# Podria ser algo tan cutre y sencillo como devolver el REPR de columns? Podria ser
# Bassicamente queremos que la imprimir un board apareszca en pantalla una cadena que te de la informacion que necesitas. Asi que antes de escribirlo te creas un board y lo imprimes.Saldra informacion inutil tendremos que sobreescribirlo para que nos de informacion util
